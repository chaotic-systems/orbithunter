# %%
import sys
sys.path.insert(0, "C:\\Users\\Matt\\Desktop\\orbithunter\\")
from orbithunter import *
import numpy as np
import matplotlib.pyplot as plt

# %%
orbit_ = read_h5('ppo_L21p90_T96p68.h5', directory="C:\\Users\\Matt\\Desktop\\orbithunter_test_data\\", data_format='kstori')
result = discretization_continuation(orbit_, new_shape=(32, 32), verbose=True, plot_intermediates=True, ftol=1e-8, precision='very_high', method='lstsq')
# Out:
# Starting lstsq. Initial residual=10.906510476674656, target=1.984e-12
# 1000000
# Converged. exiting with residual 1.592685436490381e-19
# Starting lstsq. Initial residual=11.857110647489714, target=1.9200000000000003e-12
# 201232242011000
# Converged. exiting with residual 1.828521389180744e-16
# Starting lstsq. Initial residual=8.536567623479034, target=1.856e-12
# 201000
# Converged. exiting with residual 3.1286148456912364e-13
# Starting lstsq. Initial residual=7.976095459099608, target=1.792e-12
# 112311321110000000
# Converged. exiting with residual 2.1708121563985532e-15
# Starting lstsq. Initial residual=14.12523124270906, target=1.7280000000000001e-12
# 12000000
# Converged. exiting with residual 5.05390960289749e-18
# Starting lstsq. Initial residual=21.63658203757959, target=1.6640000000000002e-12
# 0110221000
# Converged. exiting with residual 1.7648355751827438e-14
# Starting lstsq. Initial residual=14.169775942984096, target=1.6e-12
# 20201223211100111233224
# Failed to converge. Exiting with residual 0.003891572235178561

# %%
parameter_based_discretization(orbit_.orbit_parameters)
# Out:
# (194, 22)

# %%
orbit_
# Out:
# ShiftReflectionOrbitKS({"state_type": "modes", "parameters": ["1.934e+02", "2.190e+01", "0.e+00"], "field_shape": ["64", "32"]})

# %%
result.orbit
# Out:
# ShiftReflectionOrbitKS({"state_type": "modes", "parameters": ["2.039e+02", "2.206e+01", "0.e+00"], "field_shape": ["32", "32"]})
