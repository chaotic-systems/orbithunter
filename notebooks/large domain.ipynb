# %%
from __future__ import print_function, division, absolute_import
import os,sys
import sys
sys.path.insert(0, "C:\\Users\\Matt\\Desktop\\torihunter-master\\")
# sys.path.insert(0, "C:\\Users\\Matt\\Desktop\\gudorf\\KS\\python\\kstori\\Lib")

from torihunter import *
import numpy as np
import itertools
from math import pi
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# %matplotlib notebook
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
x = Orbit(L=512, T=512, time_scale=64, space_scale=64)

# %%
x.plot()
# Out:
# <img src="data:image/png;base64,..._..._..._..." width="653">

# %%
result = converge(x, method='adj', verbose=True, preconditioning=False, max_iter=10000)

# %%
y = result.Orbit

# %%
x_after_adjoint = y.convert(to='field')

# %%
fig = plt.figure()
plt.imshow(x_after_adjoint.state, cmap='jet')
_ = plt.show()

# %%
x_after_adjoint.state.shape

# %%
mx_after_adjoint.state

# %%
spacetime_mollifier[3, :]

# %%
L = 512./(2*pi)

# %%
int(L/np.sqrt(2))

# %%
fig = plt.figure()
plt.imshow()
plt.colorbar()
_ = plt.show()

# %%
44/(8*pi)

# %%
T // 10,  L // (2*pi*np.sqrt(2))

# %%
fig = plt.figure()
plt.plot(spacetime_mollifier[1,:])
plt.show()

# %%
xy[0]-sms

# %%
np.exp(-((((xy[0]-sms)**2)/(L/2))**4+(((xy[1]-tms)**2)/(L/2))**4))

# %%
fig = plt.figure()
plt.imshow(
plt.show()

# %%
T//20

# %%
rmodes = np.random.randn(*spacetime_mollifier.shape)

# %%
127
# Out:
# 127

# %%
xy[0].shape
# Out:
# (127, 31)

# %%
((xy[1]-tms)**2)/10
# Out:
# array([[ 3.6,  3.6,  3.6, ...,  3.6,  3.6,  3.6],
#        [ 2.5,  2.5,  2.5, ...,  2.5,  2.5,  2.5],
#        [ 1.6,  1.6,  1.6, ...,  1.6,  1.6,  1.6],
#        ...,
#        [48.4, 48.4, 48.4, ..., 48.4, 48.4, 48.4],
#        [52.9, 52.9, 52.9, ..., 52.9, 52.9, 52.9],
#        [57.6, 57.6, 57.6, ..., 57.6, 57.6, 57.6]])

# %%
n = 31
m = 31
L = 88
T= 120

xy = np.meshgrid(np.arange(m),np.arange(n))

spacetime_mollifier = np.exp(-(np.abs(xy[0]-sms)/8 + np.abs(xy[1]-tms)/tms))
spacetime_mollifier = np.concatenate((spacetime_mollifier, spacetime_mollifier), axis=1)
spacetime_mollifier = np.concatenate((spacetime_mollifier, spacetime_mollifier), axis=0)
spacetime_mollifier = np.concatenate((np.ones([1, 2*m]), spacetime_mollifier), axis=0)

# %%
sms
# Out:
# 19.0

# %%
tms = T//10
sms = L // (pi*np.sqrt(2))
sms = int(sms)
tms = int(tms)
mollifier_exponents = sms + -1 * np.tile(np.arange(0, m)+1, (n, 1))
mollifier = np.exp(mollifier_exponents)
mollifier[:, :sms] = 1
mollifier[tms:, :] = 0
mollifier = np.concatenate((mollifier, mollifier), axis=1)
mollifier = np.concatenate((mollifier, mollifier), axis=0)
mollifier = np.concatenate((np.ones([1, 2*m]), mollifier), axis=0)
rmodes = np.random.randn(*spacetime_mollifier.shape)

# %%
fig = plt.figure(figsize=(5,5))
plt.imshow(mollifier, cmap='jet')
plt.colorbar()
_ = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
x = Orbit(state=rmodes*spacetime_mollifier, statetype='modes', L=88, T=120, N=64, M=256)#.plot()#.spatiotemporal_mapping()

# %%
xprime = x // (0.25)

# %%
xprime.convert(to='field').plot()
# Out:
# <img src="data:image/png;base64,..._..." width="384">

# %%
result = converge(xprime, method='adj', verbose=True, preconditioning=True, max_iter=10000)
result.Orbit.plot()
# Out:
# Starting adjoint descent. Initial residual 25621.476993333148
# ........................Current residual 7.945155365263932
# ........................Current residual 4.241571831300748
# <img src="data:image/png;base64,..._..." width="384">

# %%
saved_rmodes = rmodes.copy()

# %%
10**-5
# Out:
# 0.0001

# %%
np.exp(1)**-
# Out:
# 2.718281828459045

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(np.log(np.abs(rtst.state)), cmap='jet')
plt.colorbar()
_ = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
xprime.L, xprime.T
# Out:
# (88, 120)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(np.log10(np.abs(xprime.convert(to='modes').state)), cmap='jet')
plt.colorbar()
_ = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning:
#
# divide by zero encountered in log10

# %%
xprime = x // (0.25)

# %%
xprime.convert(to='field').plot()
# Out:
# <img src="data:image/png;base64,..._..." width="384">

# %%
tst2 = converge(xprime, verbose=True, method='adj', max_iter=400)
# Out:
# Starting adjoint descent. Initial residual 52290.75727473777
# ..

# %%
tst2.Orbit.plot()
# Out:
# <img src="data:image/png;base64,..." width="384">

# %%
tst2 = converge(xprime, verbose=True)
# Out:
# Starting adjoint descent. Initial residual 13435.182619580763
# ........................Current residual 2.4345275512455467
# ........................Current residual 1.526874648384906
# ........................Current residual 1.1623080022848287
# ........................Current residual 0.9915707898639103
# ........................Current residual 0.8793219455970256
# ........................Current residual 0.7874446096178869
# ........................Current residual 0.7068993240067197
# ........................Current residual 0.6404667375124189
# ........................Current residual 0.5824362468571731
# ........................Current residual 0.5360982774138658
# ........................Current residual 0.5008525599962789
# ........................Current residual 0.4727475577917694
# ........................Current residual 0.4494173779192683
# ..Starting Least-squares Newton with backtracking. Initial residual 0.44711113524607843
# ...

# %%
tst.Orbit.plot()
# Out:
# <img src="data:image/png;base64,..._..._..." width="384">

# %%
result = converge(x, method='adj', verbose=True, preconditioning=True, max_iter=10000)

# %%
xprime.L/(2*pi*np.sqrt(2))
# Out:
# 9.903479477728167

# %%
result.Orbit.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2b6d0221bbc3> in <module>
# ----> 1 result.Orbit.plot()
#
# NameError: name 'result' is not defined

# %%
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
tst = np.tile(np.arange(16),(16,1))
for i in range(tst.shape[0]):
    tst[i,:] = np.roll(tst[i,:].reshape(1,-1), i//2, axis=1)

# %%
rtst = RelativeOrbit(state=tst, statetype='field', T=44, L=44, S = -44./16.).convert(to='modes')

# %%
rtst.mode_shape

# %%
# Out:
# Starting adjoint descent. Initial residual 4.498658160698615
# ........................Current residual 5.6500763777682365e-06
# ........................Current residual 3.720287798956304e-06
# ........................Current residual 3.0077547729801155e-06
# ........................Current residual 2.649020356042168e-06
# ........................Current residual 2.433569036083917e-06
# ........................Current residual 2.2873294862070057e-06
# .............Starting Least-squares Newton with backtracking. Initial residual 2.2239158006583595e-06
# 10

# %%
tst.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Desktop\torihunter-master\torihunter\optimize.py in __getattr__(self, name)
#      39         try:
# ---> 40             return self[name]
#      41         except KeyError:
#
# KeyError: 'plot'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e58f7af936ea> in <module>
# ----> 1 tst.plot()
#
# ~\Desktop\torihunter-master\torihunter\optimize.py in __getattr__(self, name)
#      40             return self[name]
#      41         except KeyError:
# ---> 42             raise AttributeError(name)
#      43
#      44     __setattr__ = dict.__setitem__
#
# AttributeError: plot

# %%
rtst = read_h5('ppo_L34p01_T64p70.h5').convert(to='modes')
rtst.plot()
# Out:
# <img src="data:image/png;base64,..._..." width="289">

# %%
rtst
